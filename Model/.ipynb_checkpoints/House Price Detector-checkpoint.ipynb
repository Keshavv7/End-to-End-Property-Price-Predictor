# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,10)

# %%
data = pd.read_csv('Bengaluru_House_Data.csv')
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.shape
# Out:
# (13320, 9)

# %% [markdown]
# <b> Reviewing the features </b>

# %%
# Let's first check the number of unique values in area_type feature
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
# For now let us drop some columns
data2 = data.drop(['area_type', 'availability', 'society'], axis='columns')
data2
# Out:
#                        location       size total_sqft  bath  balcony   price
# 0      Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0      1.0   51.00
# ...                         ...        ...        ...   ...      ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0      0.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0      NaN  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0      1.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0      1.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0      1.0   17.00
#
# [13320 rows x 6 columns]

# %% [markdown]
# <b> Data Cleaning and Processing </b>

# %%
#Handling NA values
data2.isnull().sum()
# Out:
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
data2['balcony'] = data2['balcony'].fillna(0) #Filling NA balcony values with 0
#Dropping rest of the rows with NA values
data3 = data2.dropna()
data3.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
data3
# Out:
#                        location       size total_sqft  bath  balcony   price
# 0      Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0      1.0   51.00
# ...                         ...        ...        ...   ...      ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0      0.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0      0.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0      1.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0      1.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0      1.0   17.00
#
# [13246 rows x 6 columns]

# %%
# We can see that the size column is very consistent in data representation
data3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
# We can convert Bedroom to BHK or just simply keep count of bedrooms as integer
data3['bedrooms'] = data3['size'].apply(lambda x: int(x.split(' ')[0]))
data3
# Out:
# /tmp/ipykernel_5464/620882368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['bedrooms'] = data3['size'].apply(lambda x: int(x.split(' ')[0]))
#                        location       size total_sqft  bath  balcony   price  \
# 0      Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0      1.0   51.00
# ...                         ...        ...        ...   ...      ...     ...
# ...

# %%
data4 = data3.drop('size', axis='columns')
data4
# Out:
#                        location total_sqft  bath  balcony   price  bedrooms
# 0      Electronic City Phase II       1056   2.0      1.0   39.07         2
# 1              Chikka Tirupathi       2600   5.0      3.0  120.00         4
# 2                   Uttarahalli       1440   2.0      3.0   62.00         3
# 3            Lingadheeranahalli       1521   3.0      1.0   95.00         3
# 4                      Kothanur       1200   2.0      1.0   51.00         2
# ...                         ...        ...   ...      ...     ...       ...
# 13315                Whitefield       3453   4.0      0.0  231.00         5
# 13316             Richards Town       3600   5.0      0.0  400.00         4
# 13317     Raja Rajeshwari Nagar       1141   2.0      1.0   60.00         2
# 13318           Padmanabhanagar       4689   4.0      1.0  488.00         4
# 13319              Doddathoguru        550   1.0      1.0   17.00         1
#
# [13246 rows x 6 columns]

# %%
data4['bedrooms'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
# We can see there exist houses with 43 bedrooms too, which is unusual.
data4[data4.bedrooms > 20]
# Out:
#                        location total_sqft  bath  balcony  price  bedrooms
# 1718  2Electronic City Phase II       8000  27.0      0.0  230.0        27
# 4684                Munnekollal       2400  40.0      0.0  660.0        43

# %%
# Clearly 2400 sqft house cannot have 43 bedrooms
data4.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
# We can see the value '1133-1384' which is a range and not an actual value
# We can take mean of these numbers. 
# Let us examine the total_sqft field more
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

data4[~data4['total_sqft'].apply(is_float)].head(20)
# Out:
#                    location      total_sqft  bath  balcony    price  bedrooms
# 30                Yelahanka     2100 - 2850   4.0      0.0  186.000         4
# 122                  Hebbal     3067 - 8156   4.0      0.0  477.000         4
# 137      8th Phase JP Nagar     1042 - 1105   2.0      0.0   54.005         2
# 165                Sarjapur     1145 - 1340   2.0      0.0   43.490         2
# 188                KR Puram     1015 - 1540   2.0      0.0   56.800         2
# 410                 Kengeri  34.46Sq. Meter   1.0      0.0   18.500         1
# 549             Hennur Road     1195 - 1440   2.0      0.0   63.770         2
# 648                 Arekere       4125Perch   9.0      0.0  265.000         9
# 661               Yelahanka     1120 - 1145   2.0      0.0   48.130         2
# 672            Bettahalsoor     3090 - 5002   4.0      0.0  445.000         4
# 772   Banashankari Stage VI     1160 - 1195   2.0      0.0   59.935         2
# ...

# %%
# We can see there are all kinds of values under sqft
# One way is to ignore all those rows with values other than ranges
def convert_to_num(x):
    words = x.split('-')
    if (len(words)==2):
        return (float(words[0])+float(words[1]))/2 #Convert range to avg
    try:
        return float(x) #Convert string nums to float
    except:
        return None # Discard everything else

data5 = data4.copy()
data5['total_sqft'] = data4['total_sqft'].apply(convert_to_num)
data5.head(20)
# Out:
#                     location  total_sqft  bath  balcony   price  bedrooms
# 0   Electronic City Phase II      1056.0   2.0      1.0   39.07         2
# 1           Chikka Tirupathi      2600.0   5.0      3.0  120.00         4
# 2                Uttarahalli      1440.0   2.0      3.0   62.00         3
# 3         Lingadheeranahalli      1521.0   3.0      1.0   95.00         3
# 4                   Kothanur      1200.0   2.0      1.0   51.00         2
# 5                 Whitefield      1170.0   2.0      1.0   38.00         2
# 6           Old Airport Road      2732.0   4.0      0.0  204.00         4
# 7               Rajaji Nagar      3300.0   4.0      0.0  600.00         4
# 8               Marathahalli      1310.0   3.0      1.0   63.25         3
# 9               Gandhi Bazar      1020.0   6.0      0.0  370.00         6
# 10                Whitefield      1800.0   2.0      2.0   70.00         3
# 11                Whitefield      2785.0   5.0      3.0  295.00         4
# ...

# %% [markdown]
# <b> Feature Engineering </b>

# %%
# We know that price per sqft is an important feature
data6 = data5.copy()
data6['price_per_sqft'] = data6['price']*100000/data6['total_sqft']
data6
# Out:
#                        location  total_sqft  bath  balcony   price  bedrooms  \
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07         2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00         4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00         3
# 3            Lingadheeranahalli      1521.0   3.0      1.0   95.00         3
# 4                      Kothanur      1200.0   2.0      1.0   51.00         2
# ...                         ...         ...   ...      ...     ...       ...
# 13315                Whitefield      3453.0   4.0      0.0  231.00         5
# 13316             Richards Town      3600.0   5.0      0.0  400.00         4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0      1.0   60.00         2
# 13318           Padmanabhanagar      4689.0   4.0      1.0  488.00         4
# 13319              Doddathoguru       550.0   1.0      1.0   17.00         1
#
#        price_per_sqft
# ...

# %%
len(data6.location.unique())
# Out:
# 1304

# %%
#Too many categories
data6.location = data6.location.apply(lambda x: x.strip()) #Removing trailing/leading spaces
location_stats = data6.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_stats
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1052

# %%
location_stats_less_than_10 = location_stats[location_stats<=10]
location_stats_less_than_10
# Out:
# location
# Basapura                 10
# 1st Block Koramangala    10
# Gunjur Palya             10
# Kalkere                  10
# Sector 1 HSR Layout      10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1052, dtype: int64

# %%
len(data6.location.unique())
# Out:
# 1293

# %%
data6.location = data6.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(data6.location.unique())
# Out:
# 242

# %%
# Now the one-hot encoding will only have around 250 columns

# Let us now remove outliers and abnormal data points

# %% [markdown]
# We may recall that there were several houses with few bedrooms and very large size or very high number of bedrooms and very low size. We can keep a rough estimate of a normal bedroom size ( should be around 200sqft to 600 sqft or so ). Any data points which violate this range are abnormal.

# %%
data6[data6.total_sqft/data6.bedrooms<300]
# Out:
#                   location  total_sqft  bath  balcony  price  bedrooms  \
# 9                    other      1020.0   6.0      0.0  370.0         6
# 45              HSR Layout       600.0   9.0      0.0  200.0         8
# 58           Murugeshpalya      1407.0   4.0      1.0  150.0         6
# 68     Devarachikkanahalli      1350.0   7.0      0.0   85.0         8
# 70                   other       500.0   3.0      2.0  100.0         3
# ...                    ...         ...   ...      ...    ...       ...
# 13277                other      1400.0   7.0      0.0  218.0         7
# 13279                other      1200.0   5.0      0.0  130.0         6
# 13281      Margondanahalli      1375.0   5.0      1.0  125.0         5
# 13303       Vidyaranyapura       774.0   5.0      3.0   70.0         5
# 13311     Ramamurthy Nagar      1500.0   9.0      2.0  250.0         7
#
#        price_per_sqft
# 9        36274.509804
# 45       33333.333333
# 58       10660.980810
# ...

# %%
# We can see that all these rows have unusual values
data6.shape
# Out:
# (13246, 7)

# %%
data7 = data6[~(data6.total_sqft/data6.bedrooms<300)]
data7
# Out:
#                        location  total_sqft  bath  balcony   price  bedrooms  \
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07         2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00         4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00         3
# 3            Lingadheeranahalli      1521.0   3.0      1.0   95.00         3
# 4                      Kothanur      1200.0   2.0      1.0   51.00         2
# ...                         ...         ...   ...      ...     ...       ...
# 13315                Whitefield      3453.0   4.0      0.0  231.00         5
# 13316                     other      3600.0   5.0      0.0  400.00         4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0      1.0   60.00         2
# 13318           Padmanabhanagar      4689.0   4.0      1.0  488.00         4
# 13319              Doddathoguru       550.0   1.0      1.0   17.00         1
#
#        price_per_sqft
# ...

# %%
# Let us check price per sqft
data7.price_per_sqft.describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
# We can see that the min and max values are too extreme
# If data follows normal distribution, then around 70% of data points should within the standard deviation of mean
def handle_extreme_price(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df], ignore_index=True)
    return df_out
final = handle_extreme_price(data7)
final
# Out:
#                   location  total_sqft  bath  balcony   price  bedrooms  \
# 0      1st Block Jayanagar      2850.0   4.0      1.0  428.00         4
# 1      1st Block Jayanagar      1630.0   3.0      2.0  194.00         3
# 2      1st Block Jayanagar      1875.0   2.0      3.0  235.00         3
# 3      1st Block Jayanagar      1200.0   2.0      0.0  130.00         3
# 4      1st Block Jayanagar      1235.0   2.0      2.0  148.00         2
# ...                    ...         ...   ...      ...     ...       ...
# 10236                other      1353.0   2.0      2.0  110.00         2
# 10237                other       812.0   1.0      0.0   26.00         1
# 10238                other      1440.0   2.0      2.0   63.93         3
# 10239                other      1075.0   2.0      2.0   48.00         2
# 10240                other      3600.0   5.0      0.0  400.00         4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# ...

# %%
# Examining the csv file also reveals that for same location, some rows are such that price for 2 bedrooms is higher than that of 3 bedrooms.
#  rows might affect our model. 
#Let us visualize this

def scatter_plotter(df, location):
    bhk2 = df[(df.location==location) & (df.bedrooms==2)]
    bhk3 = df[(df.location==location) & (df.bedrooms==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft, bhk2.price,color='blue',label='2BHK', s=50)
    plt.scatter(bhk3.total_sqft, bhk3.price,marker='*',color='red',label='3BHK', s=50)
    plt.xlabel('Total Square Feet Area')
    plt.ylabel('Price')
    plt.title(location)
    plt.legend()

# %%
scatter_plotter(final, 'Rajaji Nagar')

# %%
#We can see around 1750sqft, 2 bedroom price is higher than 3 bedrooms
# Need to remove these outliers

# %%
scatter_plotter(final, 'Hebbal')

# %% [markdown]
# One normal way is to check the mean and std for 1 bedroom apartments in one area, and then make sure that the 2 bedroom stats are above these vaues.

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bedrooms'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std' : np.std(bhk_df.price_per_sqft),
                'count' : bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bedrooms'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices, axis='index')

final2 = remove_bhk_outliers(final)
final2
# Out:
#                   location  total_sqft  bath  balcony  price  bedrooms  \
# 0      1st Block Jayanagar      2850.0   4.0      1.0  428.0         4
# 1      1st Block Jayanagar      1630.0   3.0      2.0  194.0         3
# 2      1st Block Jayanagar      1875.0   2.0      3.0  235.0         3
# 3      1st Block Jayanagar      1200.0   2.0      0.0  130.0         3
# 4      1st Block Jayanagar      1235.0   2.0      2.0  148.0         2
# ...                    ...         ...   ...      ...    ...       ...
# 10232                other      1200.0   2.0      3.0   70.0         2
# 10233                other      1800.0   1.0      1.0  200.0         1
# 10236                other      1353.0   2.0      2.0  110.0         2
# 10237                other       812.0   1.0      0.0   26.0         1
# 10240                other      3600.0   5.0      0.0  400.0         4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# ...

# %%
# Plotting the same scatterplots gives us:
scatter_plotter(final2, 'Rajaji Nagar')

# %%
scatter_plotter(final2, 'Hebbal')

# %%
# We can see that all those outliers are also removed from the data now
# We can also check the number of properties vs price per sqft

matplotlib.rcParams['figure.figsize'] = (20, 10)
plt.hist(final2.price_per_sqft, rwidth=0.5)
plt.xlabel('Price per Square Feet')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#We can see it has a rough bell curve structure
# Now let us review Bathrooms
final.bath.unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  8.,  1.,  6.,  7.,  9., 12., 16., 13.])

# %%
#We can see values above 10, which is abnormal
final2[final2.bath>10]
# Out:
#             location  total_sqft  bath  balcony  price  bedrooms  \
# 5277  Neeladri Nagar      4000.0  12.0      0.0  160.0        10
# 8486           other     12000.0  12.0      0.0  525.0        10
# 8575           other     10000.0  16.0      0.0  550.0        16
# 9308           other      6000.0  12.0      0.0  150.0        11
# 9639           other      5425.0  13.0      0.0  275.0        13
#
#       price_per_sqft
# 5277     4000.000000
# 8486     4375.000000
# 8575     5500.000000
# 9308     2500.000000
# 9639     5069.124424

# %%
# Most data points are okay except a few
# We will remove data points where #baths > #bedrooms+2

plt.hist(final2.bath, width=0.5)
plt.xlabel('Number of bathrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
final2[final2.bath > final2.bedrooms+2]
# Out:
#            location  total_sqft  bath  balcony   price  bedrooms  \
# 1626  Chikkabanavar      2460.0   7.0      2.0    80.0         4
# 5238     Nagasandra      7000.0   8.0      0.0   450.0         4
# 6711    Thanisandra      1806.0   6.0      2.0   116.0         3
# 8411          other     11338.0   9.0      1.0  1000.0         6
#
#       price_per_sqft
# 1626     3252.032520
# 5238     6428.571429
# 6711     6423.034330
# 8411     8819.897689

# %%
final3 = final2[final2.bath < final2.bedrooms+2]
final3
# Out:
#                   location  total_sqft  bath  balcony  price  bedrooms  \
# 0      1st Block Jayanagar      2850.0   4.0      1.0  428.0         4
# 1      1st Block Jayanagar      1630.0   3.0      2.0  194.0         3
# 2      1st Block Jayanagar      1875.0   2.0      3.0  235.0         3
# 3      1st Block Jayanagar      1200.0   2.0      0.0  130.0         3
# 4      1st Block Jayanagar      1235.0   2.0      2.0  148.0         2
# ...                    ...         ...   ...      ...    ...       ...
# 10232                other      1200.0   2.0      3.0   70.0         2
# 10233                other      1800.0   1.0      1.0  200.0         1
# 10236                other      1353.0   2.0      2.0  110.0         2
# 10237                other       812.0   1.0      0.0   26.0         1
# 10240                other      3600.0   5.0      0.0  400.0         4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# ...

# %%
final4 = final3.drop(['price_per_sqft'], axis='columns')
final4
# Out:
#                   location  total_sqft  bath  balcony  price  bedrooms
# 0      1st Block Jayanagar      2850.0   4.0      1.0  428.0         4
# 1      1st Block Jayanagar      1630.0   3.0      2.0  194.0         3
# 2      1st Block Jayanagar      1875.0   2.0      3.0  235.0         3
# 3      1st Block Jayanagar      1200.0   2.0      0.0  130.0         3
# 4      1st Block Jayanagar      1235.0   2.0      2.0  148.0         2
# ...                    ...         ...   ...      ...    ...       ...
# 10232                other      1200.0   2.0      3.0   70.0         2
# 10233                other      1800.0   1.0      1.0  200.0         1
# 10236                other      1353.0   2.0      2.0  110.0         2
# 10237                other       812.0   1.0      0.0   26.0         1
# 10240                other      3600.0   5.0      0.0  400.0         4
#
# [7251 rows x 6 columns]

# %%
# We shall now convert categorical text feature (location) into one hot encoded variable

dummies = pd.get_dummies(final4.location)
dummies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                     True               False                      False
# 1                     True               False                      False
# 2                     True               False                      False
# 3                     True               False                      False
# 4                     True               False                      False
# ...                    ...                 ...                        ...
# 10232                False               False                      False
# 10233                False               False                      False
# 10236                False               False                      False
# 10237                False               False                      False
# 10240                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# ...

# %%
#Note that we can drop one column, so we can drop others
final5 = pd.concat([final4, dummies.drop('other',axis='columns')], axis='columns')
final5
# Out:
#                   location  total_sqft  bath  balcony  price  bedrooms  \
# 0      1st Block Jayanagar      2850.0   4.0      1.0  428.0         4
# 1      1st Block Jayanagar      1630.0   3.0      2.0  194.0         3
# 2      1st Block Jayanagar      1875.0   2.0      3.0  235.0         3
# 3      1st Block Jayanagar      1200.0   2.0      0.0  130.0         3
# 4      1st Block Jayanagar      1235.0   2.0      2.0  148.0         2
# ...                    ...         ...   ...      ...    ...       ...
# 10232                other      1200.0   2.0      3.0   70.0         2
# 10233                other      1800.0   1.0      1.0  200.0         1
# 10236                other      1353.0   2.0      2.0  110.0         2
# 10237                other       812.0   1.0      0.0   26.0         1
# 10240                other      3600.0   5.0      0.0  400.0         4
#
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# ...

# %% [markdown]
# <b> Now we are ready to create the training and testing sets </b>

# %%
X = final5.drop(['location', 'price'], axis='columns')
y = final5['price']
X
# Out:
#        total_sqft  bath  balcony  bedrooms  1st Block Jayanagar  \
# 0          2850.0   4.0      1.0         4                 True
# 1          1630.0   3.0      2.0         3                 True
# 2          1875.0   2.0      3.0         3                 True
# 3          1200.0   2.0      0.0         3                 True
# 4          1235.0   2.0      2.0         2                 True
# ...           ...   ...      ...       ...                  ...
# 10232      1200.0   2.0      3.0         2                False
# 10233      1800.0   1.0      1.0         1                False
# 10236      1353.0   2.0      2.0         2                False
# 10237       812.0   1.0      0.0         1                False
# 10240      3600.0   5.0      0.0         4                False
#
#        1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0                   False                      False                 False
# ...

# %%
y
# Out:
# 0        428.0
# 1        194.0
# 2        235.0
# 3        130.0
# 4        148.0
#          ...
# 10232     70.0
# 10233    200.0
# 10236    110.0
# 10237     26.0
# 10240    400.0
# Name: price, Length: 7251, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)
X_train
# Out:
#       total_sqft  bath  balcony  bedrooms  1st Block Jayanagar  \
# 6646      1564.0   3.0      1.0         3                False
# 7353      3200.0   4.0      3.0         4                False
# 7622      2444.0   4.0      0.0         4                False
# 1840      1107.0   2.0      3.0         2                False
# 7652      1400.0   2.0      3.0         2                False
# ...          ...   ...      ...       ...                  ...
# 1424      1139.0   2.0      2.0         2                False
# 4293      1495.0   2.0      2.0         2                False
# 1623       950.0   2.0      1.0         2                False
# 5720      6000.0   8.0      3.0         8                False
# 1562       900.0   2.0      3.0         2                False
#
#       1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 6646               False                      False                 False
# ...

# %%
X_test
# Out:
#       total_sqft  bath  balcony  bedrooms  1st Block Jayanagar  \
# 1189      1432.0   2.0      2.0         2                False
# 6016      1032.0   2.0      1.0         2                False
# 4008       929.0   2.0      1.0         2                False
# 5036      1690.0   3.0      2.0         3                False
# 4815      1683.0   3.0      1.0         3                False
# ...          ...   ...      ...       ...                  ...
# 3274      1725.0   3.0      2.0         3                False
# 3808      1184.0   2.0      1.0         2                False
# 1342      1090.0   2.0      2.0         2                False
# 853       1115.0   2.0      1.0         2                False
# 6247      1181.0   2.0      1.0         3                False
#
#       1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 1189               False                      False                 False
# ...

# %% [markdown]
# <b> Creating the model </b>

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.8454334113886331

# %% [markdown]
# Performing K-Fold Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.82422698, 0.77159854, 0.8512903 , 0.80898801, 0.83614922])

# %% [markdown]
# Let us try some other regression models using GridSearchCV

# %%
# Model selection and Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model(X,y):
    algorithms = {
        'linear_regression' : {
            'model' : LinearRegression(),
            'params' : {
                'fit_intercept' : [True, False],
                'positive' : [True, False]
            }
        },
        'lasso' : {
            'model' : Lasso(),
            'params' : {
                'alpha' : [1,2],
                'selection' : ['random', 'cyclic']
            }
        },
        'decision_tree' : {
            'model' : DecisionTreeRegressor(),
            'params' : {
                'criterion' : ['mse', 'friedman_mse'],
                'splitter' : ['best', 'random']
            }
        }
    }
    
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algorithms.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model' : algo_name,
            'best_score' : gs.best_score_,
            'best_params' : gs.best_params_
        })
    return pd.DataFrame(scores, columns=['model','best_score','best_params'])


results = find_best_model(X, y)
results
# Out:
# /home/keshav/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/keshav/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/keshav/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py", line 1247, in fit
#     super().fit(
#   File "/home/keshav/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py", line 177, in fit
#     self._validate_params()
# ...

# %%
# We can see that the best model is Linear Regression
# Now we can predict

regression_model = LinearRegression(fit_intercept=False, positive=False)
regression_model.fit(X_train.values, y_train.values)

def predict_price(location, sqft, bath, balcony, bedrooms):
    loc_index = np.where(X.columns==location)[0][0]
    
    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = balcony
    x[3] = bedrooms
    if loc_index >= 0:
        x[loc_index] = 1
        
    return regression_model.predict([x])[0]

# %%
predict_price('1st Phase JP Nagar', 1000, 2, 1, 2)
# Out:
# 84.32050993201358

# %%
place = 'Indira Nagar'
size_in_sqft = 2000
bedrooms = 3
bathrooms = 3
balcony = 2
price = (predict_price(place, size_in_sqft, bathrooms, balcony, bedrooms))
if (price < 100):
    print(int(price), 'lakhs rupees')
else:
    ans = '{:.2f}'.format(price/100)
    print(ans, 'crore rupees')
# Out:
# 2.63 crore rupees

# %% [markdown]
# <b> Exporting model to a pickle file </b>

# %%
import pickle
with open('bengaluru_property_price_model.pickle', 'wb') as f:
    pickle.dump(regression_model, f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open('columns.json', 'w') as f:
    f.write(json.dumps(columns))
